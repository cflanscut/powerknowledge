# %%
import sys
import time
from sklearn.model_selection import train_test_split
from sklearn import tree
import numpy as np
import joblib
sys.path.append('data/')
sys.path.append('data/source/')
sys.path.append('data/model/deep_learning_model')
sys.path.append('data/model/knowledge_model')
from read_PLAID_data import read_processed_data

# %%
start_reading_time=time.time()
x_is_cool, y_is_cool = read_processed_data('is_cool',
                           type_header='extra label',
                           direaction=1,
                           offset=30)
x_is_cool=x_is_cool[:,1:]

x_is_heat, y_is_heat = read_processed_data('is_heat',
                           type_header='extra label',
                           direaction=1,
                           offset=30)
x_is_heat=x_is_heat[:,1:]

x_is_light, y_is_light = read_processed_data('is_light',
                           type_header='extra label',
                           direaction=1,
                           offset=30)
x_is_light=x_is_light[:,1:]

x_is_rotate, y_is_rotate = read_processed_data('is_rotate',
                           type_header='extra label',
                           direaction=1,
                           offset=30)
x_is_rotate=x_is_rotate[:,1:]

load_transformer = {'I': 0, 'R': 1, 'NL': 0}
x_load, y_load = read_processed_data('load',
                           direaction=1,
                           offset=30,
                           Transformer=load_transformer)
x_load=x_load[:,1:]   
print('finished loading data, cost %.3fs'%(time.time()-start_reading_time))
# Out:
# finished loading data, cost 95.924s

# %%
x_is_cool_train,x_is_cool_test,y_is_cool_train,y_is_cool_test=train_test_split(x_is_cool,y_is_cool,test_size=0.5,random_state=0)
x_is_heat_train,x_is_heat_test,y_is_heat_train,y_is_heat_test=train_test_split(x_is_heat,y_is_heat,test_size=0.5,random_state=0)
x_is_light_train,x_is_light_test,y_is_light_train,y_is_light_test=train_test_split(x_is_light,y_is_light,test_size=0.5,random_state=0)
x_is_rotate_train,x_is_rotate_test,y_is_rotate_train,y_is_rotate_test=train_test_split(x_is_rotate,y_is_rotate,test_size=0.5,random_state=0)
x_load_train,x_load_test,y_load_train,y_load_test=train_test_split(x_load,y_load,test_size=0.5,random_state=0)

md=range(1,10)
mss=[2,5,10,15,25,50,100,150,200]
for i in md:
    for j in mss:
        start_tree_time = time.time()
        cooler_clf = tree.DecisionTreeClassifier(max_depth=i, min_samples_split=j)
        cooler_clf.fit(x_is_cool_train, y_is_cool_train)
        
        start_tree_time = time.time()
        heater_clf = tree.DecisionTreeClassifier(max_depth=i, min_samples_split=j)
        heater_clf.fit(x_is_heat_train, y_is_heat_train)
        
        start_tree_time = time.time()
        lighter_clf = tree.DecisionTreeClassifier(max_depth=i, min_samples_split=j)
        lighter_clf.fit(x_is_light_train, y_is_light_train)
        
        start_tree_time = time.time()
        rotater_clf = tree.DecisionTreeClassifier(max_depth=i, min_samples_split=j)
        rotater_clf.fit(x_is_rotate_train, y_is_rotate_train)
        
        start_tree_time = time.time()
        load_clf = tree.DecisionTreeClassifier(max_depth=i, min_samples_split=j)
        load_clf.fit(x_load_train, y_load_train)
        
        print('md=%03d,mss=%03d: cooler_score %3.4f heater_score %3.4f lighter_score %3.4f rotater_score %3.4f load_score %3.4f ' % (i,j,cooler_clf.score(x_is_cool_test, y_is_cool_test),heater_clf.score(x_is_heat_test, y_is_heat_test),lighter_clf.score(x_is_light_test, y_is_light_test),rotater_clf.score(x_is_rotate_test, y_is_rotate_test),load_clf.score(x_load_test, y_load_test)))
# md=009,mss=010: cooler_score 0.9104 heater_score 0.8998 lighter_score 0.9360 rotater_score 0.8731 load_score 0.9648
# md=009,mss=015: cooler_score 0.9009 heater_score 0.8998 lighter_score 0.9254 rotater_score 0.8721 load_score 0.9584
# md=009,mss=025: cooler_score 0.9104 heater_score 0.8966 lighter_score 0.9275 rotater_score 0.8731 load_score 0.9542
# md=009,mss=050: cooler_score 0.8849 heater_score 0.9051 lighter_score 0.9179 rotater_score 0.8603 load_score 0.9467
# md=009,mss=100: cooler_score 0.8987 heater_score 0.8635 lighter_score 0.9051 rotater_score 0.8422 load_score 0.9467
# md=009,mss=150: cooler_score 0.8785 heater_score 0.8369 lighter_score 0.9126 rotater_score 0.8209 load_score 0.9414
# md=009,mss=200: cooler_score 0.8785 heater_score 0.8369 lighter_score 0.9168 rotater_score 0.8006 load_score 0.9456

# %%
start_train_time=time.time()
x_is_cool_train,x_is_cool_test,y_is_cool_train,y_is_cool_test=train_test_split(x_is_cool,y_is_cool,test_size=0.5,random_state=0)
start_tree_time = time.time()
cooler_clf = tree.DecisionTreeClassifier(max_depth=3, min_samples_split=100)
cooler_clf.fit(x_is_cool_train, y_is_cool_train)

x_is_heat_train,x_is_heat_test,y_is_heat_train,y_is_heat_test=train_test_split(x_is_heat,y_is_heat,test_size=0.5,random_state=0)
start_tree_time = time.time()
heater_clf = tree.DecisionTreeClassifier(max_depth=4, min_samples_split=50)
heater_clf.fit(x_is_heat_train, y_is_heat_train)

x_is_light_train,x_is_light_test,y_is_light_train,y_is_light_test=train_test_split(x_is_light,y_is_light,test_size=0.5,random_state=0)
start_tree_time = time.time()
lighter_clf = tree.DecisionTreeClassifier(max_depth=4, min_samples_split=10)
lighter_clf.fit(x_is_light_train, y_is_light_train)

x_is_rotate_train,x_is_rotate_test,y_is_rotate_train,y_is_rotate_test=train_test_split(x_is_rotate,y_is_rotate,test_size=0.5,random_state=0)
start_tree_time = time.time()
rotater_clf = tree.DecisionTreeClassifier(max_depth=7, min_samples_split=25)
rotater_clf.fit(x_is_rotate_train, y_is_rotate_train)

x_load_train,x_load_test,y_load_train,y_load_test=train_test_split(x_load,y_load,test_size=0.5,random_state=0)
start_tree_time = time.time()
load_clf = tree.DecisionTreeClassifier(max_depth=4, min_samples_split=25)
load_clf.fit(x_load_train, y_load_train)
print('finished training, cost %.3fs'%(time.time()-start_train_time))
# Out:
# finished training, cost 0.261s

# %%
start_time = time.time()
print('start reading data')
x_light, y_light = read_processed_data('type',
                                       selected_label=[
                                           'Compact Fluorescent Lamp',
                                           'Incandescent Light Bulb', 'Laptop'
                                       ],
                                       direaction=1,
                                       offset=30,
                                       each_lenth=1)
x_light = x_light[:, 1:]
x_cold, y_cold = read_processed_data(
    'type',
    selected_label=['Fridge', 'Air Conditioner'],
    direaction=1,
    offset=30,
    each_lenth=1)
x_cold = x_cold[:, 1:]
x_dislight_R, y_dislight_R = read_processed_data(
    'type',
    selected_label=['Hairdryer', 'Heater', 'Coffee maker', 'Water kettle'],
    direaction=1,
    offset=30,
    each_lenth=1)
x_dislight_R = x_dislight_R[:, 1:]
x_heat_I, y_heat_I = read_processed_data(
    'type',
    selected_label=['Microwave', 'Hair Iron', 'Soldering Iron'],
    direaction=1,
    offset=30,
    each_lenth=1)
x_heat_I = x_heat_I[:, 1:]
x_rotate_I, y_rotate_I = read_processed_data('type',
                                             selected_label=[
                                                 'Air Conditioner', 'Vacuum',
                                                 'Fan', 'Washing Machine',
                                                 'Blender'
                                             ],
                                             direaction=1,
                                             offset=30,
                                             each_lenth=1)
x_rotate_I = x_rotate_I[:, 1:]
print('finished loading data, cost %2.2fs' % (time.time() - start_time))
# Out:
# start reading data
# finished loading data, cost 95.66s

# %%
x_light_train, x_light_test, y_light_train, y_light_test = train_test_split(
    x_light, y_light, test_size=0.5)
x_cold_train, x_cold_test, y_cold_train, y_cold_test = train_test_split(
    x_cold, y_cold, test_size=0.5)
x_dislight_R_train, x_dislight_R_test, y_dislight_R_train, y_dislight_R_test = train_test_split(
    x_dislight_R, y_dislight_R, test_size=0.5)
x_heat_I_train, x_heat_I_test, y_heat_I_train, y_heat_I_test = train_test_split(
    x_heat_I, y_heat_I, test_size=0.5)
x_rotate_I_train, x_rotate_I_test, y_rotate_I_train, y_rotate_I_test = train_test_split(
    x_rotate_I, y_rotate_I, test_size=0.5)

md=range(1,10)
mss=[2,5,10,15,25,50,100,150,200]
for i in md:
    for j in mss:
        light_tree = tree.DecisionTreeClassifier(max_depth=i, min_samples_leaf=j)
        cold_tree = tree.DecisionTreeClassifier(max_depth=i, min_samples_leaf=j)
        dislight_R_tree = tree.DecisionTreeClassifier(max_depth=i, min_samples_leaf=j)
        heat_I_tree = tree.DecisionTreeClassifier(max_depth=i, min_samples_leaf=j)
        rotate_I_tree = tree.DecisionTreeClassifier(max_depth=i, min_samples_leaf=j)

        light_tree.fit(x_light_train, y_light_train)
        cold_tree.fit(x_cold_train, y_cold_train)
        dislight_R_tree.fit(x_dislight_R_train, y_dislight_R_train)
        heat_I_tree.fit(x_heat_I_train, y_heat_I_train)
        rotate_I_tree.fit(x_rotate_I_train, y_rotate_I_train)

        print('md=%03d,mss=%03d: light_tree_score %3.4f cold_tree_score %3.4f dislight_R_tree_score %3.4f heat_I_tree_score %3.4f rotate_I_tree_score %3.4f ' % (i,j,light_tree.score(x_light_test, y_light_test),cold_tree.score(x_cold_test, y_cold_test),dislight_R_tree.score(x_dislight_R_test, y_dislight_R_test),heat_I_tree.score(x_heat_I_test, y_heat_I_test),rotate_I_tree.score(x_rotate_I_test, y_rotate_I_test)))
# Out:
# md=001,mss=002: light_tree_score 0.6656 cold_tree_score 0.7692 dislight_R_tree_score 0.7273 heat_I_tree_score 0.9478 rotate_I_tree_score 0.4658
# md=001,mss=005: light_tree_score 0.6656 cold_tree_score 0.7692 dislight_R_tree_score 0.7273 heat_I_tree_score 0.9565 rotate_I_tree_score 0.4658
# md=001,mss=010: light_tree_score 0.6656 cold_tree_score 0.7692 dislight_R_tree_score 0.7273 heat_I_tree_score 0.9565 rotate_I_tree_score 0.4658
# md=001,mss=015: light_tree_score 0.6656 cold_tree_score 0.7692 dislight_R_tree_score 0.7273 heat_I_tree_score 0.9304 rotate_I_tree_score 0.4658
# md=001,mss=025: light_tree_score 0.6656 cold_tree_score 0.7692 dislight_R_tree_score 0.7273 heat_I_tree_score 0.8609 rotate_I_tree_score 0.4658
# md=001,mss=050: light_tree_score 0.6656 cold_tree_score 0.7692 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.4658
# md=001,mss=100: light_tree_score 0.6656 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.4692
# md=001,mss=150: light_tree_score 0.5927 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.3390
# md=001,mss=200: light_tree_score 0.3576 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.3390
# md=002,mss=002: light_tree_score 0.9404 cold_tree_score 0.9231 dislight_R_tree_score 0.7784 heat_I_tree_score 0.9913 rotate_I_tree_score 0.7021
# md=002,mss=005: light_tree_score 0.9404 cold_tree_score 0.9231 dislight_R_tree_score 0.7841 heat_I_tree_score 0.9652 rotate_I_tree_score 0.7021
# md=002,mss=010: light_tree_score 0.9238 cold_tree_score 0.7564 dislight_R_tree_score 0.7784 heat_I_tree_score 0.9565 rotate_I_tree_score 0.7021
# md=002,mss=015: light_tree_score 0.9106 cold_tree_score 0.7756 dislight_R_tree_score 0.7841 heat_I_tree_score 0.9391 rotate_I_tree_score 0.7021
# md=002,mss=025: light_tree_score 0.9172 cold_tree_score 0.7692 dislight_R_tree_score 0.7557 heat_I_tree_score 0.8609 rotate_I_tree_score 0.7021
# md=002,mss=050: light_tree_score 0.9172 cold_tree_score 0.7692 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.6164
# md=002,mss=100: light_tree_score 0.6656 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.4692
# md=002,mss=150: light_tree_score 0.5927 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.3390
# md=002,mss=200: light_tree_score 0.3576 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.3390
# md=003,mss=002: light_tree_score 0.9106 cold_tree_score 0.8590 dislight_R_tree_score 0.8352 heat_I_tree_score 0.9913 rotate_I_tree_score 0.7055
# md=003,mss=005: light_tree_score 0.9404 cold_tree_score 0.9231 dislight_R_tree_score 0.8466 heat_I_tree_score 0.9739 rotate_I_tree_score 0.7055
# md=003,mss=010: light_tree_score 0.9238 cold_tree_score 0.7436 dislight_R_tree_score 0.8182 heat_I_tree_score 0.9565 rotate_I_tree_score 0.7055
# md=003,mss=015: light_tree_score 0.9106 cold_tree_score 0.7756 dislight_R_tree_score 0.7841 heat_I_tree_score 0.9391 rotate_I_tree_score 0.7055
# md=003,mss=025: light_tree_score 0.9172 cold_tree_score 0.7692 dislight_R_tree_score 0.7557 heat_I_tree_score 0.8609 rotate_I_tree_score 0.7021
# md=003,mss=050: light_tree_score 0.9172 cold_tree_score 0.7692 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.6164
# md=003,mss=100: light_tree_score 0.6656 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.4692
# md=003,mss=150: light_tree_score 0.5927 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.3390
# md=003,mss=200: light_tree_score 0.3576 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.3390
# md=004,mss=002: light_tree_score 0.9007 cold_tree_score 0.8269 dislight_R_tree_score 0.8295 heat_I_tree_score 0.9652 rotate_I_tree_score 0.8082
# md=004,mss=005: light_tree_score 0.9172 cold_tree_score 0.9167 dislight_R_tree_score 0.8693 heat_I_tree_score 1.0000 rotate_I_tree_score 0.7911
# md=004,mss=010: light_tree_score 0.9238 cold_tree_score 0.7372 dislight_R_tree_score 0.8239 heat_I_tree_score 0.9565 rotate_I_tree_score 0.7295
# md=004,mss=015: light_tree_score 0.8974 cold_tree_score 0.7756 dislight_R_tree_score 0.7784 heat_I_tree_score 0.9391 rotate_I_tree_score 0.7055
# md=004,mss=025: light_tree_score 0.9172 cold_tree_score 0.7692 dislight_R_tree_score 0.7557 heat_I_tree_score 0.8609 rotate_I_tree_score 0.7397
# md=004,mss=050: light_tree_score 0.9172 cold_tree_score 0.7692 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.6164
# md=004,mss=100: light_tree_score 0.6656 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.4692
# md=004,mss=150: light_tree_score 0.5927 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.3390
# md=004,mss=200: light_tree_score 0.3576 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.3390
# md=005,mss=002: light_tree_score 0.9272 cold_tree_score 0.8782 dislight_R_tree_score 0.8693 heat_I_tree_score 1.0000 rotate_I_tree_score 0.8390
# md=005,mss=005: light_tree_score 0.9040 cold_tree_score 0.9103 dislight_R_tree_score 0.8182 heat_I_tree_score 0.9739 rotate_I_tree_score 0.8390
# md=005,mss=010: light_tree_score 0.9238 cold_tree_score 0.7500 dislight_R_tree_score 0.8239 heat_I_tree_score 0.9478 rotate_I_tree_score 0.7603
# md=005,mss=015: light_tree_score 0.8874 cold_tree_score 0.7756 dislight_R_tree_score 0.7841 heat_I_tree_score 0.9391 rotate_I_tree_score 0.6884
# md=005,mss=025: light_tree_score 0.9172 cold_tree_score 0.7692 dislight_R_tree_score 0.7557 heat_I_tree_score 0.8609 rotate_I_tree_score 0.7397
# md=005,mss=050: light_tree_score 0.9172 cold_tree_score 0.7692 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.6164
# md=005,mss=100: light_tree_score 0.6656 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.4692
# md=005,mss=150: light_tree_score 0.5927 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.3390
# md=005,mss=200: light_tree_score 0.3576 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.3390
# md=006,mss=002: light_tree_score 0.8808 cold_tree_score 0.8590 dislight_R_tree_score 0.8409 heat_I_tree_score 0.9739 rotate_I_tree_score 0.8767
# md=006,mss=005: light_tree_score 0.9404 cold_tree_score 0.9103 dislight_R_tree_score 0.8239 heat_I_tree_score 0.9739 rotate_I_tree_score 0.8527
# md=006,mss=010: light_tree_score 0.9238 cold_tree_score 0.7372 dislight_R_tree_score 0.8182 heat_I_tree_score 0.9478 rotate_I_tree_score 0.7123
# md=006,mss=015: light_tree_score 0.9040 cold_tree_score 0.7756 dislight_R_tree_score 0.7784 heat_I_tree_score 0.9304 rotate_I_tree_score 0.6884
# md=006,mss=025: light_tree_score 0.9172 cold_tree_score 0.7692 dislight_R_tree_score 0.7557 heat_I_tree_score 0.8609 rotate_I_tree_score 0.7397
# md=006,mss=050: light_tree_score 0.9172 cold_tree_score 0.7692 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.6164
# md=006,mss=100: light_tree_score 0.6656 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.4692
# md=006,mss=150: light_tree_score 0.5927 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.3390
# md=006,mss=200: light_tree_score 0.3576 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.3390
# md=007,mss=002: light_tree_score 0.9106 cold_tree_score 0.8462 dislight_R_tree_score 0.8466 heat_I_tree_score 0.9739 rotate_I_tree_score 0.8322
# md=007,mss=005: light_tree_score 0.9470 cold_tree_score 0.9167 dislight_R_tree_score 0.8295 heat_I_tree_score 1.0000 rotate_I_tree_score 0.8562
# md=007,mss=010: light_tree_score 0.9238 cold_tree_score 0.7564 dislight_R_tree_score 0.8182 heat_I_tree_score 0.9565 rotate_I_tree_score 0.7397
# md=007,mss=015: light_tree_score 0.9272 cold_tree_score 0.7756 dislight_R_tree_score 0.7784 heat_I_tree_score 0.9391 rotate_I_tree_score 0.6884
# md=007,mss=025: light_tree_score 0.9172 cold_tree_score 0.7692 dislight_R_tree_score 0.7557 heat_I_tree_score 0.8609 rotate_I_tree_score 0.7397
# md=007,mss=050: light_tree_score 0.9172 cold_tree_score 0.7692 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.6164
# md=007,mss=100: light_tree_score 0.6656 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.4692
# md=007,mss=150: light_tree_score 0.5927 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.3390
# md=007,mss=200: light_tree_score 0.3576 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.3390
# md=008,mss=002: light_tree_score 0.9106 cold_tree_score 0.8397 dislight_R_tree_score 0.8920 heat_I_tree_score 0.9739 rotate_I_tree_score 0.8425
# md=008,mss=005: light_tree_score 0.9073 cold_tree_score 0.9167 dislight_R_tree_score 0.8352 heat_I_tree_score 0.9739 rotate_I_tree_score 0.8322
# md=008,mss=010: light_tree_score 0.9238 cold_tree_score 0.7436 dislight_R_tree_score 0.8239 heat_I_tree_score 0.9565 rotate_I_tree_score 0.7158
# md=008,mss=015: light_tree_score 0.9040 cold_tree_score 0.7756 dislight_R_tree_score 0.7841 heat_I_tree_score 0.9304 rotate_I_tree_score 0.6884
# md=008,mss=025: light_tree_score 0.9172 cold_tree_score 0.7692 dislight_R_tree_score 0.7557 heat_I_tree_score 0.8609 rotate_I_tree_score 0.7397
# md=008,mss=050: light_tree_score 0.9172 cold_tree_score 0.7692 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.6164
# md=008,mss=100: light_tree_score 0.6656 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.4692
# md=008,mss=150: light_tree_score 0.5927 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.3390
# md=008,mss=200: light_tree_score 0.3576 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.3390
# md=009,mss=002: light_tree_score 0.9106 cold_tree_score 0.8782 dislight_R_tree_score 0.8409 heat_I_tree_score 0.9913 rotate_I_tree_score 0.8356
# md=009,mss=005: light_tree_score 0.9470 cold_tree_score 0.8910 dislight_R_tree_score 0.8693 heat_I_tree_score 0.9739 rotate_I_tree_score 0.8219
# md=009,mss=010: light_tree_score 0.9238 cold_tree_score 0.7436 dislight_R_tree_score 0.8182 heat_I_tree_score 0.9565 rotate_I_tree_score 0.6986
# md=009,mss=015: light_tree_score 0.9139 cold_tree_score 0.7756 dislight_R_tree_score 0.7841 heat_I_tree_score 0.9391 rotate_I_tree_score 0.6884
# md=009,mss=025: light_tree_score 0.9172 cold_tree_score 0.7692 dislight_R_tree_score 0.7557 heat_I_tree_score 0.8609 rotate_I_tree_score 0.7397
# md=009,mss=050: light_tree_score 0.9172 cold_tree_score 0.7692 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.6164
# md=009,mss=100: light_tree_score 0.6656 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.4692
# md=009,mss=150: light_tree_score 0.5927 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.3390
# md=009,mss=200: light_tree_score 0.3576 cold_tree_score 0.6090 dislight_R_tree_score 0.6761 heat_I_tree_score 0.8609 rotate_I_tree_score 0.3390

# %%
x_light_train, x_light_test, y_light_train, y_light_test = train_test_split(
    x_light, y_light, test_size=0.5)
x_cold_train, x_cold_test, y_cold_train, y_cold_test = train_test_split(
    x_cold, y_cold, test_size=0.5)
x_dislight_R_train, x_dislight_R_test, y_dislight_R_train, y_dislight_R_test = train_test_split(
    x_dislight_R, y_dislight_R, test_size=0.5)
x_heat_I_train, x_heat_I_test, y_heat_I_train, y_heat_I_test = train_test_split(
    x_heat_I, y_heat_I, test_size=0.5)
x_rotate_I_train, x_rotate_I_test, y_rotate_I_train, y_rotate_I_test = train_test_split(
    x_rotate_I, y_rotate_I, test_size=0.5)

light_tree = tree.DecisionTreeClassifier(max_depth=2, min_samples_leaf=5)
cold_tree = tree.DecisionTreeClassifier(max_depth=2, min_samples_leaf=5)
dislight_R_tree = tree.DecisionTreeClassifier(max_depth=4, min_samples_leaf=5)
heat_I_tree = tree.DecisionTreeClassifier(max_depth=2, min_samples_leaf=2)
rotate_I_tree = tree.DecisionTreeClassifier(max_depth=6, min_samples_leaf=2)

light_tree.fit(x_light_train, y_light_train)
cold_tree.fit(x_cold_train, y_cold_train)
dislight_R_tree.fit(x_dislight_R_train, y_dislight_R_train)
heat_I_tree.fit(x_heat_I_train, y_heat_I_train)
rotate_I_tree.fit(x_rotate_I_train, y_rotate_I_train)
# Out:
# DecisionTreeClassifier(max_depth=6, min_samples_leaf=2)

# %%
x_test = np.concatenate((x_light_test, x_cold_test, x_dislight_R_test,
                         x_heat_I_test, x_rotate_I_test),
                        axis=0)
y_test = np.concatenate((y_light_test, y_cold_test, y_dislight_R_test,
                         y_heat_I_test, y_rotate_I_test),
                        axis=0)

def classify_model(inputs):
    outputs = []
    tree_outputs = []
    for x in inputs:
        y = []
        j = []
        x = x.reshape(1, -1)
        lighter_clf_result = lighter_clf.predict(x)
        colder_clf_result = cooler_clf.predict(x)
        heater_clf_result = heater_clf.predict(x)
        rotater_clf_result = rotater_clf.predict(x)
        load_clf_result = load_clf.predict(x)
        if lighter_clf_result[0] == '1':
            y.append(light_tree.predict(x))
            j.append([
                'Compact Fluorescent Lamp', 'Incandescent Light Bulb', 'Laptop'
            ])
        if colder_clf_result[0] == '1':
            y.append(cold_tree.predict(x))
            j.append(['Fridge', 'Air Conditioner'])
        if lighter_clf_result[0] == '0' and load_clf_result[0] == 1:
            y.append(dislight_R_tree.predict(x))
            j.append(['Hairdryer', 'Heater', 'Coffee maker', 'Water kettle'])
        if heater_clf_result[0] == '1' and load_clf_result[0] == 0:
            y.append(heat_I_tree.predict(x))
            j.append(['Microwave', 'Hair Iron', 'Soldering Iron'])
        if rotater_clf_result[0] == '1' and load_clf_result[0] == 0:
            y.append(rotate_I_tree.predict(x))
            j.append([
                'Air Conditioner', 'Vacuum', 'Fan', 'Washing Machine',
                'Blender'
            ])
        if y == []:
            outputs.append('')
            tree_outputs.append([''])
            continue
        outputs.append(max(y, key=y.count))
        tree_outputs.append(sum(j, []))
    return outputs, tree_outputs


y_predict, tree_predict = classify_model(x_test)
count0 = 0
count1 = 0

for i in range(len(y_predict)):
    if y_test[i] in tree_predict[i]:
        count0 += 1
    if y_predict[i] == y_test[i]:
        count1 += 1
print('tree_classification\'s accuracy: %.6f'%(count0 / len(y_predict)))
print('type_classification\'s accuracy: %.6f'%(count1 / len(y_predict)))
# Out:
# 0.8885686839577329
# 0.7742555235350624
